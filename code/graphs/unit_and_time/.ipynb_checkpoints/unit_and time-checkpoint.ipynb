# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import seaborn as sns

# %%
#create dataframe from the csv file
df=pd.read_csv("sfpd_dispatch_data_subset.csv")

# %%
df.received_timestamp=pd.to_datetime(df.received_timestamp)
df.on_scene_timestamp=pd.to_datetime(df.on_scene_timestamp)

# %%
times= pd.DataFrame(df['on_scene_timestamp']-df['received_timestamp'])   #find timedelta

# %%
times['unit_type']= (df['unit_type'])

# %%
times.head()
# Out:
#          0 unit_type
# 0 00:17:26     MEDIC
# 1 00:13:57     MEDIC
# 2 00:05:41    ENGINE
# 3 00:04:02    ENGINE
# 4 00:06:07     CHIEF

# %%
times['minutes'] = (times[0].dt.total_seconds()//60) #convert to minutes

# %%
times.dropna(inplace=True) #remove nan values
# Out:
#             0       unit_type  minutes
# 0    00:17:26           MEDIC     17.0
# 1    00:13:57           MEDIC     13.0
# 2    00:05:41          ENGINE      5.0
# 3    00:04:02          ENGINE      4.0
# 4    00:06:07           CHIEF      6.0
# 5    00:05:47          ENGINE      5.0
# 6    00:11:18          ENGINE     11.0
# 7    00:08:27           MEDIC      8.0
# 8    00:05:58          ENGINE      5.0
# 9    00:06:45           MEDIC      6.0
# 10   00:17:46           MEDIC     17.0
# 11   00:16:10           MEDIC     16.0
# 12   00:07:32          ENGINE      7.0
# 13   00:12:33         PRIVATE     12.0
# 14   00:08:14           MEDIC      8.0
# 15   00:20:40    RESCUE SQUAD     20.0
# 16   00:07:26          ENGINE      7.0
# 17   00:11:52          ENGINE     11.0
# 18   00:10:43           MEDIC     10.0
# 20   00:06:46           MEDIC      6.0
# 21   00:04:29          ENGINE      4.0
# 22   00:03:43          ENGINE      3.0
# 23   00:12:54          ENGINE     12.0
# 24   00:08:23           MEDIC      8.0
# 25   00:06:55           MEDIC      6.0
# 26   00:06:22           MEDIC      6.0
# 27   03:15:43           MEDIC    195.0
# 28   00:09:50           MEDIC      9.0
# 29   00:03:01          ENGINE      3.0
# 30   00:03:59           MEDIC      3.0
# ...       ...             ...      ...
# 9960 00:05:52          ENGINE      5.0
# 9962 00:18:15           MEDIC     18.0
# 9963 00:05:57          ENGINE      5.0
# 9965 00:19:57    RESCUE SQUAD     19.0
# 9967 00:05:37           CHIEF      5.0
# 9968 00:06:00          ENGINE      6.0
# 9970 00:04:16          ENGINE      4.0
# 9971 00:04:41          ENGINE      4.0
# 9972 00:25:44           MEDIC     25.0
# 9974 00:03:52  RESCUE CAPTAIN      3.0
# 9975 00:10:20         PRIVATE     10.0
# 9976 00:06:42          ENGINE      6.0
# 9977 00:13:15         PRIVATE     13.0
# 9978 00:06:37          ENGINE      6.0
# 9979 00:04:45          ENGINE      4.0
# 9980 00:05:43          ENGINE      5.0
# 9981 00:09:01           MEDIC      9.0
# 9983 00:04:44         PRIVATE      4.0
# 9984 00:08:44           MEDIC      8.0
# 9985 00:09:08  RESCUE CAPTAIN      9.0
# 9987 00:04:16          ENGINE      4.0
# 9988 00:08:35           MEDIC      8.0
# 9989 00:06:45           MEDIC      6.0
# 9990 00:00:00          ENGINE     -0.0
# 9991 00:07:13           MEDIC      7.0
# 9992 00:00:00          ENGINE     -0.0
# 9993 00:02:56           MEDIC      2.0
# 9995 00:03:43          ENGINE      3.0
# 9996 00:04:33          ENGINE      4.0
# 9999 00:10:42           MEDIC     10.0
#
# [8085 rows x 3 columns]

# %%
avg_times=times.groupby('unit_type', as_index=False)['minutes'].mean() #group to find mean

# %%
avg_times.set_index('unit_type')
# Out:
#                   minutes
# unit_type
# CHIEF            9.538462
# ENGINE           7.534033
# INVESTIGATION   26.181818
# MEDIC           11.225997
# PRIVATE         11.516161
# RESCUE CAPTAIN  12.855491
# RESCUE SQUAD     6.675676
# SUPPORT         23.300000
# TRUCK            6.894904

# %%
plt.rcParams["xtick.labelsize"] = 1
sns.set(style="white", context="talk")
x=avg_times['unit_type']
y=avg_times['minutes']
fig, ax = plt.subplots()
fig.set_size_inches(15, 10)
g=sns.barplot(x, y, palette="OrRd" )
g.set_xticklabels(g.get_xticklabels(),rotation=30)
plt.show()
